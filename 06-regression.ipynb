# %%
# file = open('csv_files/salary.csv','x')
# file.close()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('csv_files/salaryData.csv')
dataset=dataset.dropna()
dataset.to_csv('new_dataset.csv')

# %%
# d=all(dataset["Years of Experience"].isnull().values==True)
# d
# if any(dataset["Years of Experience"].isnull()==False):
#       print(dataset["Years of Experience"])
# dataset

# %%
dataset = dataset.iloc[:,4:]
dataset
# Out:
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [373 rows x 2 columns]

# %%
X = dataset.iloc[:,0:-1].values
X
# Out:
# array([[ 5. ],
#        [ 3. ],
#        [15. ],
#        [ 7. ],
#        [20. ],
#        [ 2. ],
#        [12. ],
#        [ 4. ],
#        [ 1. ],
#        [10. ],
#        [ 3. ],
#        [18. ],
#        [ 6. ],
#        [14. ],
#        [ 2. ],
#        [16. ],
#        [ 7. ],
#        [12. ],
#        [ 0. ],
#        [22. ],
#        [ 5. ],
#        [19. ],
#        [ 2. ],
#        [ 9. ],
#        [13. ],
#        [ 3. ],
#        [11. ],
#        [ 1. ],
#        [15. ],
#        [ 6. ],
#        [25. ],
#        [ 4. ],
#        [ 3. ],
#        [10. ],
#        [20. ],
#        [ 2. ],
#        [ 7. ],
#        [14. ],
#        [ 1. ],
#        [21. ],
#        [ 5. ],
#        [18. ],
#        [ 3. ],
#        [ 8. ],
#        [13. ],
#        [ 2. ],
#        [ 5. ],
#        [16. ],
#        [11. ],
#        [ 0. ],
#        [22. ],
#        [ 7. ],
#        [12. ],
#        [19. ],
#        [ 3. ],
#        [ 9. ],
#        [ 2. ],
#        [17. ],
# ...

# %%
Y = dataset.iloc[:,1:].values
Y
# Out:
# array([[ 90000.],
#        [ 65000.],
#        [150000.],
#        [ 60000.],
#        [200000.],
#        [ 55000.],
#        [120000.],
#        [ 80000.],
#        [ 45000.],
#        [110000.],
#        [ 75000.],
#        [140000.],
#        [ 65000.],
#        [130000.],
#        [ 40000.],
#        [125000.],
#        [ 90000.],
#        [115000.],
#        [ 35000.],
#        [180000.],
#        [ 80000.],
#        [190000.],
#        [ 50000.],
#        [ 60000.],
#        [140000.],
#        [ 45000.],
#        [110000.],
#        [ 40000.],
#        [140000.],
#        [ 90000.],
#        [250000.],
#        [ 55000.],
#        [ 75000.],
#        [ 65000.],
#        [170000.],
#        [ 45000.],
#        [ 60000.],
#        [115000.],
#        [ 40000.],
#        [160000.],
#        [ 80000.],
#        [190000.],
#        [ 60000.],
#        [ 45000.],
#        [130000.],
#        [ 40000.],
#        [ 75000.],
#        [180000.],
#        [120000.],
#        [ 35000.],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 1/3,random_state = 0)

# %%
len(X_train)
# Out:
# 248

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train,Y_train,color = 'red')
plt.plot(X_train,model.predict(X_train),color = 'blue')
plt.show()

# %%
plt.scatter(X_test,Y_test,color = 'red')
plt.plot(X_train,model.predict(X_train),color = 'blue')
plt.show()

# %%
exp = float(input("Enter years of experience = "))
exp = np.array([[exp]])
predicted_salary = model.predict(exp)[0][0]
print("Your predicted_salary = ",predicted_salary)
# Out:
# Enter years of experience = 4
# Your predicted_salary =  59171.0574565674

# %%
# for testing data
predicted_salary = model.predict(X_test)
print("Your predicted_salary = ",predicted_salary)
# Out:
# Your predicted_salary =  [[ 45357.74838216]
#  [ 45357.74838216]
#  [ 52264.40291936]
#  [142050.91190303]
#  [ 86797.67560539]
#  [142050.91190303]
#  [ 59171.05745657]
#  [128237.60282862]
#  [ 45357.74838216]
#  [176584.18458905]
#  [ 66077.71199377]
#  [114424.29375421]
#  [135144.25736582]
#  [ 79891.02106818]
#  [107517.639217  ]
#  [ 59171.05745657]
#  [ 52264.40291936]
#  [ 45357.74838216]
#  [142050.91190303]
#  [169677.53005185]
#  [ 86797.67560539]
#  [ 86797.67560539]
#  [100610.9846798 ]
#  [ 45357.74838216]
#  [190397.49366346]
#  [ 45357.74838216]
#  [ 66077.71199377]
#  [ 66077.71199377]
#  [114424.29375421]
#  [ 52264.40291936]
#  [ 66077.71199377]
#  [114424.29375421]
#  [114424.29375421]
#  [135144.25736582]
#  [ 52264.40291936]
#  [114424.29375421]
#  [ 52264.40291936]
#  [107517.639217  ]
#  [100610.9846798 ]
#  [114424.29375421]
#  [128237.60282862]
#  [162770.87551464]
#  [142050.91190303]
#  [169677.53005185]
#  [162770.87551464]
#  [ 45357.74838216]
# ...
